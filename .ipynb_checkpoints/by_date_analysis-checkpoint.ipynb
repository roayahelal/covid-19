# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_json("https://pomber.github.io/covid19/timeseries.json")

# %%
#taking a look at the structure of data for a specefic country
data["US"].head()
# Out:
# 0    {'date': '2020-1-22', 'confirmed': 1, 'deaths'...
# 1    {'date': '2020-1-23', 'confirmed': 1, 'deaths'...
# 2    {'date': '2020-1-24', 'confirmed': 2, 'deaths'...
# 3    {'date': '2020-1-25', 'confirmed': 2, 'deaths'...
# 4    {'date': '2020-1-26', 'confirmed': 5, 'deaths'...
# Name: US, dtype: object

# %%
#the objective is to create a table of countries and dates as columns with confirmed cases as values
data_to_use = pd.DataFrame()

# %%
#creating a dates column
dates = []
for x in range(0,len(data)):
    date_extracted = data[y][x]["date"]
    dates.append(date_extracted)
data_to_use["date"]=dates

# %%
#making a list of countries
countries = data.columns
#adding ccountries as columns
for i in countries:
    data_to_use[i] = 0
    data_to_use[i] = data_to_use[i].astype(float)

# %%
#updating values of cells to confirmed cases
for country in countries:
    for x in range(0,len(data)):
        data_to_use.at[x,country] = data[country][x]["confirmed"]

# %%
#previewing results
for i in countries:
    data_to_use[i].astype(float)
data_to_use.tail()
# Out:
#          date  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 61  2020-3-23         40.0    104.0    230.0    133.0     3.0
# 62  2020-3-24         74.0    123.0    264.0    164.0     3.0
# 63  2020-3-25         84.0    146.0    302.0    188.0     3.0
# 64  2020-3-26         94.0    174.0    367.0    224.0     4.0
# 65  2020-3-27        110.0    186.0    409.0    267.0     4.0
#
#     Antigua and Barbuda  Argentina  Armenia  Australia  ...  Timor-Leste  \
# 61                  3.0      301.0    235.0     1682.0  ...          1.0
# 62                  3.0      387.0    249.0     2044.0  ...          1.0
# 63                  3.0      387.0    265.0     2364.0  ...          1.0
# 64                  7.0      502.0    290.0     2810.0  ...          1.0
# 65                  7.0      589.0    329.0     3143.0  ...          1.0
#
#     Belize  Laos  Libya  West Bank and Gaza  Guinea-Bissau  Mali  \
# 61     1.0   0.0    0.0                59.0            0.0   0.0
# 62     1.0   2.0    1.0                59.0            0.0   0.0
# 63     2.0   3.0    1.0                59.0            2.0   2.0
# 64     2.0   6.0    1.0                84.0            2.0   4.0
# 65     2.0   6.0    1.0                91.0            2.0  11.0
#
#     Saint Kitts and Nevis  Kosovo  Burma
# 61                    0.0     0.0    0.0
# 62                    0.0     0.0    0.0
# 63                    2.0     0.0    0.0
# 64                    2.0    71.0    0.0
# 65                    2.0    86.0    8.0
#
# [5 rows x 177 columns]

# %%
#creating a growth factor df
growth_data_to_use = data_to_use.copy()

# %%
#updating values to growth factor
for country in countries:
    for x in range(1,len(data)):
        if data_to_use[country][x-1] != 0:
            growth_data_to_use.at[x,country] = data_to_use[country][x] / data_to_use[country][x-1]
        else: 
            growth_data_to_use.at[x,country] = data_to_use[country][x]

# %%
growth_data_to_use["US"]
# Out:
# 0     1.000000
# 1     1.000000
# 2     2.000000
# 3     1.000000
# 4     2.500000
#         ...
# 61    1.317676
# 62    1.225625
# 63    1.224004
# 64    1.274529
# 65    1.212570
# Name: US, Length: 66, dtype: float64

# %%
growth_data_to_use.tail()
# Out:
#          date  Afghanistan   Albania   Algeria   Andorra    Angola  \
# 61  2020-3-23     1.000000  1.168539  1.144279  1.176991  1.500000
# 62  2020-3-24     1.850000  1.182692  1.147826  1.233083  1.000000
# 63  2020-3-25     1.135135  1.186992  1.143939  1.146341  1.000000
# 64  2020-3-26     1.119048  1.191781  1.215232  1.191489  1.333333
# 65  2020-3-27     1.170213  1.068966  1.114441  1.191964  1.000000
#
#     Antigua and Barbuda  Argentina   Armenia  Australia  ...  Timor-Leste  \
# 61             3.000000   1.131579  1.211340   1.085862  ...          1.0
# 62             1.000000   1.285714  1.059574   1.215220  ...          1.0
# 63             1.000000   1.000000  1.064257   1.156556  ...          1.0
# 64             2.333333   1.297158  1.094340   1.188663  ...          1.0
# 65             1.000000   1.173307  1.134483   1.118505  ...          1.0
#
#     Belize  Laos  Libya  West Bank and Gaza  Guinea-Bissau  Mali  \
# 61     1.0   0.0    0.0            1.134615            0.0  0.00
# 62     1.0   2.0    1.0            1.000000            0.0  0.00
# 63     2.0   1.5    1.0            1.000000            2.0  2.00
# 64     1.0   2.0    1.0            1.423729            1.0  2.00
# 65     1.0   1.0    1.0            1.083333            1.0  2.75
#
#     Saint Kitts and Nevis     Kosovo  Burma
# 61                    0.0   0.000000    0.0
# 62                    0.0   0.000000    0.0
# 63                    2.0   0.000000    0.0
# 64                    1.0  71.000000    0.0
# 65                    1.0   1.211268    8.0
#
# [5 rows x 177 columns]

# %%
#plotting the data to preview
plt.plot(growth_data_to_use["date"][:3], growth_data_to_use["US"][:3] )

# %%
#saving growth as json
growth_data_to_use.to_json("growth.json")
