# %%
import os
from bs4 import BeautifulSoup as bs
import requests
from splinter import Browser
import pandas as pd
import pprint
import datetime as dt

# %%
url_corona = "https://www.worldometers.info/coronavirus/#countries"
html_corona = requests.get(url_corona)
html_corona = html_corona.text
#html_corona

# %%
soup_corona = bs(html_corona, 'html.parser')

# %%
corona_table = soup_corona.find(class_="table-bordered")

corona_table = str(corona_table)

# %%
corona_df = pd.read_html(corona_table)[0]

#replacing blanks with 0
corona_df.fillna(0,inplace = True)

#removing the total row)
corona_df = corona_df[~corona_df['Country,Other'].isin(['Total:', 'Total', 'total'])]
corona_df.to_csv('new_data.csv')
#replace items using wild card and regex to have that applied
corona_df["NewCases"].replace("\,","",regex = True, inplace = True)
corona_df["NewCases"].replace("\+","", regex = True, inplace = True)
corona_df["NewCases"] = corona_df["NewCases"].astype("float")
corona_df["Date"]= dt.datetime.today()

# %%
corona_df
# Out:
#               Country,Other  TotalCases  NewCases  TotalDeaths NewDeaths  \
# 0                       USA      123271   19145.0       2202.0      +506
# 1                     Italy       92472    5974.0      10023.0      +889
# 2                     Spain       73235    7516.0       5982.0      +844
# 3                   Germany       57695    6824.0        433.0       +82
# 4                    France       37575    4611.0       2314.0      +319
# ..                      ...         ...       ...          ...       ...
# 196   Saint Kitts and Nevis           2       0.0          0.0         0
# 197        Papua New Guinea           1       0.0          0.0         0
# 198  St. Vincent Grenadines           1       0.0          0.0         0
# 199             Timor-Leste           1       0.0          0.0         0
# 200                   China       81394       0.0       3295.0         0
#
#      TotalRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop  \
# 0            3231.0       117838            2666.0             372.0
# 1           12384.0        70065            3856.0            1529.0
# 2           12285.0        54968            4165.0            1566.0
# 3            8481.0        48781            1581.0             689.0
# 4            5700.0        29561            4273.0             576.0
# ..              ...          ...               ...               ...
# 196             0.0            2               0.0              38.0
# 197             0.0            1               0.0               0.1
# 198             1.0            0               0.0               9.0
# 199             0.0            1               0.0               0.8
# 200         74971.0         3128             886.0              57.0
#
#      Deaths/1M pop 1stcase                       Date
# 0              7.0  Jan 20 2020-03-28 19:36:02.574926
# 1            166.0  Jan 29 2020-03-28 19:36:02.574926
# 2            128.0  Jan 30 2020-03-28 19:36:02.574926
# 3              5.0  Jan 26 2020-03-28 19:36:02.574926
# 4             35.0  Jan 23 2020-03-28 19:36:02.574926
# ..             ...     ...                        ...
# 196            0.0  Mar 24 2020-03-28 19:36:02.574926
# 197            0.0  Mar 19 2020-03-28 19:36:02.574926
# 198            0.0  Mar 10 2020-03-28 19:36:02.574926
# 199            0.0  Mar 20 2020-03-28 19:36:02.574926
# 200            2.0  Jan 10 2020-03-28 19:36:02.574926
#
# [201 rows x 12 columns]

# %%
# adding lat long info 
countries_df = pd.read_csv("country_lan_lng.csv",engine='python')
merged = corona_df.merge(countries_df, left_on='Country,Other', right_on='name')
df_used = merged.drop(countries_df.columns[0:-2], axis=1)

df_used.rename(columns={"Country,Other":"Country","Serious,Critical": "CriticalCases"}, inplace = True)
#replace items using wild card and regex to have that applied
df_used["NewCases"].replace("\,","",regex = True, inplace = True)
df_used["NewCases"].replace("\+","", regex = True, inplace = True)
df_used["ClosedCases"] = df_used["TotalDeaths"] +  df_used["TotalRecovered"]

df_used["ClosedDeathRate"] = df_used["TotalDeaths"]/df_used["ClosedCases"]
df_used["ClosedDeathRate"].fillna(0,inplace = True)

total_cases = df_used["TotalCases"].sum()
total_closed_cases = df_used["ClosedCases"].sum()

df_used["Weight"] = [x/total_closed_cases for x in df_used["ClosedCases"]]

# #checking if total weight is 1 
# validate_weight = df_used["Weight"].sum()


df_used["DeathRateXWeight"] = df_used["TotalDeaths"] /df_used["TotalCases"] *df_used["Weight"]
df_used["DeathRateXWeight"].sum()
# Out:
# 0.053418024446266144

# %%
df_used.to_csv('data.csv')
df_used.to_html('data.html')

# %%
corona_json = df_used.to_json(orient='records')
df_used.to_json('data.json',orient='records')

# %%
corona_json
# Out:
# '[{"Country":"USA","TotalCases":123271,"NewCases":19145.0,"TotalDeaths":2202.0,"NewDeaths":"+506","TotalRecovered":3231.0,"ActiveCases":117838,"CriticalCases":2666.0,"Tot\\u00a0Cases\\/1M pop":372.0,"Deaths\\/1M pop":7.0,"1stcase":"Jan 20","Date":1585424162574,"Longitude":-97.922211,"Latitude":39.381266,"ClosedCases":5433.0,"ClosedDeathRate":0.4053009387,"Weight":0.0316648988,"DeathRateXWeight":0.0005656327},{"Country":"Italy","TotalCases":92472,"NewCases":5974.0,"TotalDeaths":10023.0,"NewDeaths":"+889","TotalRecovered":12384.0,"ActiveCases":70065,"CriticalCases":3856.0,"Tot\\u00a0Cases\\/1M pop":1529.0,"Deaths\\/1M pop":166.0,"1stcase":"Jan 29","Date":1585424162574,"Longitude":12.07001339,"Latitude":42.79662641,"ClosedCases":22407.0,"ClosedDeathRate":0.447315571,"Weight":0.1305936659,"DeathRateXWeight":0.0141549908},{"Country":"Spain","TotalCases":73235,"NewCases":7516.0,"TotalDeaths":5982.0,"NewDeaths":"+844","TotalRecovered":12285.0,"ActiveCases":54968,"CriticalCases":4165.0,"Tot\\u00a0Cases\\/1M pop":1566.0,"Deaths\\/1M pop":128.0,"1stcase":"Jan 30","Date":1585424162574,"Longitude":-3.64755047,"Latitude":40.24448698,"ClosedCases":18267.0,"ClosedDeathRate":0.327475776,"Weight":0.1064646983,"DeathRateXWeight":0.0086962767},{"Country":"Germany","TotalCases":57695,"NewCases":6824.0,"TotalDeaths":433.0,"NewDeaths":"+82","TotalRecovered":8481.0,"ActiveCases":48781,"CriticalCases":1581.0,"Tot\\u00a0Cases\\/1M pop":689.0,"Deaths\\/1M pop":5.0,"1stcase":"Jan 26","Date":1585424162574,"Longitude":10.38578051,"Latitude":51.10698181,"Closed